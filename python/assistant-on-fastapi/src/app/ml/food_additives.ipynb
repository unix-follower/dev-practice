# %%
import pandas as pd

file_path = "../../../../../data/pubchem/PubChem_Food-Additives-and-Ingredients.csv"
food_additives_df = pd.read_csv(file_path)
food_additives_df
# Out:
# /var/folders/kr/drklfx3s76ldd7v9jv96hf1h0000gn/T/ipykernel_60234/2564876742.py:4: DtypeWarning: Columns (30,33,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   food_additives_df = pd.read_csv(file_path)
#        Compound_CID                                               Name  \
# 0                 4                                 1-Amino-2-propanol
# 1                 6                               Dinitrochlorobenzene
# 2                 8               2,3-Dihydroxy-3-methylpentanoic acid
# 3                17          2,3-Dihydropyridine-2,6-dicarboxylic acid
# 4                19                          2,3-Dihydroxybenzoic acid
# ...             ...                                                ...
# 56089     168499111                                        Iron;oxygen
# 56090     169423541  3,5,5-trimethyl-4-[(1E,3E,5E,7E,9E)-3,7,12,16-...
# 56091     170841985  4-[[[5-(6-aminopurin-9-yl)-4-hydroxy-3-phospho...
# ...

# %%
display(food_additives_df.describe())
food_additives_df.query("Compound_CID == 4")
# Out:
#        Compound_CID  Molecular_Weight    Polar_Area    Complexity  \
# count  5.609400e+04      56094.000000  56094.000000  56094.000000
# mean   1.112412e+08        767.217035     93.590079    941.820936
# std    4.745969e+07        263.734697     75.310403    418.925423
# min    4.000000e+00          1.008000      0.000000      0.000000
# 25%    1.317549e+08        695.100000     78.900000    781.000000
# 50%    1.317729e+08        835.400000     78.900000    933.000000
# 75%    1.318082e+08        927.400000     78.900000   1120.000000
# max    1.708490e+08       3740.500000   1740.000000   9740.000000
#
#               XLogP  Heavy_Atom_Count  H-Bond_Donor_Count  \
# count  55670.000000      56094.000000        56094.000000
# mean      17.637523         54.281207            1.053803
# std        9.054801         18.753147            3.067893
# min      -25.600000          0.000000            0.000000
# 25%       13.200000         49.000000            0.000000
# ...
